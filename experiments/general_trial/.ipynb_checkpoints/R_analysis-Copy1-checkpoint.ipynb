# %%
# load the experiment design
doe <- read.csv("general_trial_run_1_description.csv", header = TRUE)  
# load the results
results <- read.csv("straight-run-trial general experiment template-table.csv", skip=6, header = TRUE)

# %%
# rename the index of the experiment design data
colnames(doe)[1] <- "experiment.number"

# %%
# merge the results with the experiment factors
data <- merge(results, doe, by = "experiment.number")

# %%
plot(data)
# Out:
# plot without title

# %%
cor(data)
# Out:
#                               experiment.number X.run.number. X.step.
# experiment.number              1.000000000       0.999994500  -0.004304240
# X.run.number.                  0.999994500       1.000000000  -0.004307704
# X.step.                       -0.004304240      -0.004307704   1.000000000
# objective.mine.speed           0.006269502       0.006284595  -0.988260144
# objective.mine.position        0.006269502       0.006284595  -0.988260144
# objective.mine.detected.ratio  0.009602171       0.009744260   0.001324501
# turn.radius                   -0.051269131      -0.051268849   0.005025643
# uuv.speed                     -0.062942785      -0.062942439  -0.032967822
# nav.bearing.std               -0.042650111      -0.042649876  -0.013616494
# nav.velocity.std.cm            0.057005575       0.057005261  -0.033571534
# max.obs.dist                  -0.008096105      -0.008096061  -0.007477925
# obs.influence                  0.007998180       0.007998136  -0.016639012
# sonar_ping_rate                0.048719254       0.048718987   0.030923090
# side_angle                     0.043229969       0.043229731   0.008841189
# side_low_range                 0.063106216       0.063105869  -0.017401577
# side_hi_range                 -0.007559052      -0.007559010   0.002902888
# side_p_detect                 -0.059316825      -0.059316499   0.031289698
# forward_angle                 -0.092452818      -0.092452310   0.008432335
# forward_low_range             -0.003204192      -0.003204174   0.035128257
# forward_hi_range              -0.049736869      -0.049736595  -0.006395926
# forward_p_detect               0.052862227       0.052861936   0.021977802
# current.heading               -0.114199019      -0.114198391   0.006818353
# drift.speed                   -0.040999427      -0.040999201  -0.031999610
#                               objective.mine.speed objective.mine.position
# experiment.number              0.006269502          0.006269502
# X.run.number.                  0.006284595          0.006284595
# X.step.                       -0.988260144         -0.988260144
# objective.mine.speed           1.000000000          1.000000000
# objective.mine.position        1.000000000          1.000000000
# objective.mine.detected.ratio  0.097898555          0.097898555
# turn.radius                   -0.003277880         -0.003277880
# uuv.speed                      0.032648134          0.032648134
# nav.bearing.std                0.014649186          0.014649186
# nav.velocity.std.cm            0.034211278          0.034211278
# max.obs.dist                   0.007960524          0.007960524
# obs.influence                  0.017468048          0.017468048
# sonar_ping_rate               -0.029623395         -0.029623395
# side_angle                    -0.006570640         -0.006570640
# side_low_range                 0.020906027          0.020906027
# side_hi_range                 -0.002999913         -0.002999913
# side_p_detect                 -0.027830850         -0.027830850
# forward_angle                 -0.011095101         -0.011095101
# forward_low_range             -0.031375904         -0.031375904
# forward_hi_range               0.005016463          0.005016463
# forward_p_detect              -0.021637317         -0.021637317
# current.heading               -0.003907635         -0.003907635
# drift.speed                    0.030053651          0.030053651
#                               objective.mine.detected.ratio turn.radius
# experiment.number              0.009602171                  -0.051269131
# X.run.number.                  0.009744260                  -0.051268849
# X.step.                        0.001324501                   0.005025643
# objective.mine.speed           0.097898555                  -0.003277880
# objective.mine.position        0.097898555                  -0.003277880
# objective.mine.detected.ratio  1.000000000                   0.020020194
# turn.radius                    0.020020194                   1.000000000
# uuv.speed                      0.003026335                   0.076281518
# nav.bearing.std                0.007226743                   0.049385390
# nav.velocity.std.cm           -0.004200853                  -0.033048719
# max.obs.dist                  -0.010096536                  -0.044077755
# obs.influence                  0.017240776                   0.024286021
# sonar_ping_rate                0.013293352                  -0.027935941
# side_angle                     0.010867371                  -0.080263428
# side_low_range                 0.033800846                  -0.017330072
# side_hi_range                  0.020800469                  -0.058403701
# side_p_detect                  0.021356850                   0.078276684
# forward_angle                 -0.004279512                   0.026066094
# forward_low_range              0.007065063                   0.027511511
# forward_hi_range              -0.010949824                   0.005139670
# forward_p_detect               0.002350460                  -0.010582765
# current.heading                0.027901026                  -0.013806876
# drift.speed                   -0.015124207                  -0.060124881
#                               uuv.speed    nav.bearing.std nav.velocity.std.cm
# experiment.number             -0.062942785 -0.042650111     5.700557e-02
# X.run.number.                 -0.062942439 -0.042649876     5.700526e-02
# X.step.                       -0.032967822 -0.013616494    -3.357153e-02
# objective.mine.speed           0.032648134  0.014649186     3.421128e-02
# objective.mine.position        0.032648134  0.014649186     3.421128e-02
# objective.mine.detected.ratio  0.003026335  0.007226743    -4.200853e-03
# turn.radius                    0.076281518  0.049385390    -3.304872e-02
# uuv.speed                      1.000000000  0.030243340     2.457573e-02
# nav.bearing.std                0.030243340  1.000000000     4.342373e-02
# nav.velocity.std.cm            0.024575730  0.043423728     1.000000e+00
# max.obs.dist                  -0.002691183 -0.044058494     5.168104e-02
# obs.influence                 -0.093613099 -0.035124751     1.140377e-02
# sonar_ping_rate               -0.080819973 -0.049345089     1.765701e-05
# side_angle                     0.079500843  0.032328672    -4.316395e-02
# side_low_range                 0.017085679  0.045660051     7.619562e-03
# side_hi_range                 -0.074071645  0.071113693     2.692768e-02
# side_p_detect                 -0.001000984  0.079997964    -1.027611e-01
# forward_angle                  0.046618361  0.012723056     3.226672e-03
# forward_low_range              0.032383185 -0.026047047     1.044239e-01
# forward_hi_range              -0.018890322  0.050083116    -2.931803e-02
# forward_p_detect              -0.053051747  0.049922959    -2.664698e-02
# current.heading                0.051218750 -0.069400434    -4.781184e-02
# drift.speed                   -0.025881840  0.002311261     2.543829e-03
#                               ... side_angle    side_low_range side_hi_range
# experiment.number             ...  0.0432299692  0.063106216   -0.007559052
# X.run.number.                 ...  0.0432297314  0.063105869   -0.007559010
# X.step.                       ...  0.0088411890 -0.017401577    0.002902888
# objective.mine.speed          ... -0.0065706405  0.020906027   -0.002999913
# objective.mine.position       ... -0.0065706405  0.020906027   -0.002999913
# objective.mine.detected.ratio ...  0.0108673709  0.033800846    0.020800469
# turn.radius                   ... -0.0802634280 -0.017330072   -0.058403701
# uuv.speed                     ...  0.0795008430  0.017085679   -0.074071645
# nav.bearing.std               ...  0.0323286723  0.045660051    0.071113693
# nav.velocity.std.cm           ... -0.0431639543  0.007619562    0.026927680
# max.obs.dist                  ... -0.0568469558 -0.067589150   -0.049768690
# obs.influence                 ... -0.0300468863  0.093180782    0.017976408
# sonar_ping_rate               ...  0.1760514295 -0.050402360    0.071215431
# side_angle                    ...  1.0000000000 -0.072913134    0.045841977
# side_low_range                ... -0.0729131342  1.000000000    0.001504500
# side_hi_range                 ...  0.0458419768  0.001504500    1.000000000
# side_p_detect                 ...  0.1105900295  0.042171467    0.057175284
# forward_angle                 ... -0.0215496853  0.082955399    0.034582426
# forward_low_range             ... -0.0004464441  0.141223682    0.034023982
# forward_hi_range              ...  0.0106604089  0.008352020   -0.048712928
# forward_p_detect              ... -0.0303880179  0.104297477    0.004075891
# current.heading               ... -0.0012550043  0.071824105   -0.030088258
# drift.speed                   ... -0.1059931716  0.067188975    0.031246776
#                               side_p_detect forward_angle forward_low_range
# experiment.number             -0.059316825  -0.0924528184 -0.0032041915
# X.run.number.                 -0.059316499  -0.0924523100 -0.0032041739
# X.step.                        0.031289698   0.0084323349  0.0351282572
# objective.mine.speed          -0.027830850  -0.0110951013 -0.0313759040
# objective.mine.position       -0.027830850  -0.0110951013 -0.0313759040
# objective.mine.detected.ratio  0.021356850  -0.0042795117  0.0070650626
# turn.radius                    0.078276684   0.0260660944  0.0275115109
# uuv.speed                     -0.001000984   0.0466183614  0.0323831849
# nav.bearing.std                0.079997964   0.0127230562 -0.0260470471
# nav.velocity.std.cm           -0.102761129   0.0032266725  0.1044238574
# max.obs.dist                   0.010518790  -0.0166154845  0.0553326213
# obs.influence                  0.047149716   0.0001214826 -0.0587148473
# sonar_ping_rate                0.043838337  -0.0672407943 -0.0272570229
# side_angle                     0.110590029  -0.0215496853 -0.0004464441
# side_low_range                 0.042171467   0.0829553992  0.1412236820
# side_hi_range                  0.057175284   0.0345824259  0.0340239816
# side_p_detect                  1.000000000  -0.0251321897  0.0182751712
# forward_angle                 -0.025132190   1.0000000000  0.0174084924
# forward_low_range              0.018275171   0.0174084924  1.0000000000
# forward_hi_range               0.045507032  -0.0312154556 -0.0531238037
# forward_p_detect              -0.021051669   0.0906587883  0.0736384563
# current.heading                0.049198089  -0.0046701462 -0.0502508300
# drift.speed                   -0.024681630   0.0211991822 -0.1012594729
#                               forward_hi_range forward_p_detect current.heading
# experiment.number             -0.049736869      0.052862227     -0.114199019
# X.run.number.                 -0.049736595      0.052861936     -0.114198391
# X.step.                       -0.006395926      0.021977802      0.006818353
# objective.mine.speed           0.005016463     -0.021637317     -0.003907635
# objective.mine.position        0.005016463     -0.021637317     -0.003907635
# objective.mine.detected.ratio -0.010949824      0.002350460      0.027901026
# turn.radius                    0.005139670     -0.010582765     -0.013806876
# uuv.speed                     -0.018890322     -0.053051747      0.051218750
# nav.bearing.std                0.050083116      0.049922959     -0.069400434
# nav.velocity.std.cm           -0.029318029     -0.026646976     -0.047811836
# max.obs.dist                  -0.006703778     -0.062183193      0.055960048
# obs.influence                 -0.014859949      0.018306130      0.052429081
# sonar_ping_rate               -0.042478800     -0.030105696      0.011419770
# side_angle                     0.010660409     -0.030388018     -0.001255004
# side_low_range                 0.008352020      0.104297477      0.071824105
# side_hi_range                 -0.048712928      0.004075891     -0.030088258
# side_p_detect                  0.045507032     -0.021051669      0.049198089
# forward_angle                 -0.031215456      0.090658788     -0.004670146
# forward_low_range             -0.053123804      0.073638456     -0.050250830
# forward_hi_range               1.000000000      0.007453353     -0.024007892
# forward_p_detect               0.007453353      1.000000000      0.016887213
# current.heading               -0.024007892      0.016887213      1.000000000
# drift.speed                   -0.132199161      0.023865197      0.100014481
#                               drift.speed
# experiment.number             -0.040999427
# X.run.number.                 -0.040999201
# X.step.                       -0.031999610
# objective.mine.speed           0.030053651
# objective.mine.position        0.030053651
# objective.mine.detected.ratio -0.015124207
# turn.radius                   -0.060124881
# uuv.speed                     -0.025881840
# nav.bearing.std                0.002311261
# nav.velocity.std.cm            0.002543829
# max.obs.dist                  -0.013925189
# obs.influence                 -0.034440367
# sonar_ping_rate                0.032354240
# side_angle                    -0.105993172
# side_low_range                 0.067188975
# side_hi_range                  0.031246776
# side_p_detect                 -0.024681630
# forward_angle                  0.021199182
# forward_low_range             -0.101259473
# forward_hi_range              -0.132199161
# forward_p_detect               0.023865197
# current.heading                0.100014481
# drift.speed                    1.000000000

# %%
colnames(data)
# Out:
#  [1] "experiment.number"             "X.run.number."
#  [3] "X.step."                       "objective.mine.speed"
#  [5] "objective.mine.position"       "objective.mine.detected.ratio"
#  [7] "turn.radius"                   "uuv.speed"
#  [9] "nav.bearing.std"               "nav.velocity.std.cm"
# [11] "max.obs.dist"                  "obs.influence"
# [13] "sonar_ping_rate"               "side_angle"
# [15] "side_low_range"                "side_hi_range"
# [17] "side_p_detect"                 "forward_angle"
# [19] "forward_low_range"             "forward_hi_range"
# [21] "forward_p_detect"              "current.heading"
# [23] "drift.speed"

# %%
plot(results)
# Out:
# plot without title

# %%
boxplot(data$uuv.speed,data$objective.mine.speed)
# Out:
# plot without title

# %%
boxplot(data$objective.mine.speed, data$forward_p_detect)
# Out:
# plot without title

# %%
describe(doe)
# Out:
# doe
#
#  18  Variables      300  Observations
# --------------------------------------------------------------------------------
# experiment.number
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1    149.5    100.3    14.95    29.90
#      .25      .50      .75      .90      .95
#    74.75   149.50   224.25   269.10   284.05
#
# lowest :   0   1   2   3   4, highest: 295 296 297 298 299
# --------------------------------------------------------------------------------
# turn.radius
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1       11    6.018    2.940    3.849
#      .25      .50      .75      .90      .95
#    6.510   11.011   15.486   18.172   19.075
#
# lowest :  2.034124  2.074839  2.175022  2.190554  2.269681
# highest: 19.752929 19.804491 19.855277 19.891463 19.989747
# --------------------------------------------------------------------------------
# uuv.speed
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1        3   0.6689    2.104    2.202
#      .25      .50      .75      .90      .95
#    2.501    2.998    3.498    3.797    3.899
#
# lowest : 2.005145 2.009429 2.018798 2.021381 2.032693
# highest: 3.972797 3.975847 3.982639 3.990877 3.996359
# --------------------------------------------------------------------------------
# nav.bearing.std
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1        2    1.338   0.2106   0.4105
#      .25      .50      .75      .90      .95
#   1.0048   1.9949   2.9968   3.5942   3.7994
#
# lowest : 0.006041339 0.026104244 0.035969792 0.046252233 0.058515818
# highest: 3.934274962 3.950838657 3.968308243 3.983217214 3.998550054
# --------------------------------------------------------------------------------
# nav.velocity.std.cm
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1    4.999    3.344   0.5242   1.0020
#      .25      .50      .75      .90      .95
#   2.4973   5.0000   7.4919   8.9887   9.4987
#
# lowest : 0.009407459 0.040172059 0.098107403 0.118413681 0.163869569
# highest: 9.846594501 9.873609642 9.902930210 9.963935590 9.991333958
# --------------------------------------------------------------------------------
# max.obs.dist
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1      5.5     3.01    1.467    1.901
#      .25      .50      .75      .90      .95
#    3.245    5.497    7.746    9.082    9.548
#
# lowest : 1.015524 1.039875 1.067886 1.094241 1.130005
# highest: 9.858583 9.898040 9.925355 9.942478 9.972011
# --------------------------------------------------------------------------------
# obs.influence
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1     2.75    1.505   0.7376   0.9575
#      .25      .50      .75      .90      .95
#   1.6323   2.7454   3.8682   4.5390   4.7682
#
# lowest : 0.5012225 0.5280622 0.5448913 0.5507754 0.5721936
# highest: 4.9277250 4.9504617 4.9672211 4.9826524 4.9992287
# --------------------------------------------------------------------------------
# sonar_ping_rate
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1     15.5    9.698    2.505    3.956
#      .25      .50      .75      .90      .95
#    8.305   15.471   22.740   27.079   28.548
#
# lowest :  1.066863  1.156254  1.270637  1.306916  1.436170
# highest: 29.560085 29.683184 29.748248 29.889906 29.971809
# --------------------------------------------------------------------------------
# side_angle
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1       70    33.44    25.19    30.29
#      .25      .50      .75      .90      .95
#    44.99    70.04    94.97   109.90   114.92
#
# lowest :  20.31670  20.63717  20.69541  21.01414  21.35431
# highest: 118.51004 118.93440 119.10798 119.59798 119.71049
# --------------------------------------------------------------------------------
# side_low_range
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1       20    13.38    2.085    4.031
#      .25      .50      .75      .90      .95
#   10.059   19.980   30.012   35.954   37.963
#
# lowest :  0.06128919  0.21451054  0.29729779  0.47766096  0.58431551
# highest: 39.42791727 39.48694768 39.64396489 39.81671975 39.95225338
# --------------------------------------------------------------------------------
# side_hi_range
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1      600    267.6    242.4    280.4
#      .25      .50      .75      .90      .95
#    400.7    600.8    798.9    919.2    959.4
#
# lowest : 202.3883 205.2020 205.7872 208.8482 211.5728
# highest: 988.3968 991.7239 994.4639 994.7922 999.0434
# --------------------------------------------------------------------------------
# side_p_detect
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1     0.75   0.1672   0.5260   0.5508
#      .25      .50      .75      .90      .95
#   0.6251   0.7500   0.8746   0.9497   0.9743
#
# lowest : 0.5009467 0.5024887 0.5045955 0.5064484 0.5081731
# highest: 0.9917286 0.9949782 0.9956955 0.9969417 0.9992612
# --------------------------------------------------------------------------------
# forward_angle
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1       55    23.41    23.67    27.14
#      .25      .50      .75      .90      .95
#    37.49    54.99    72.44    82.99    86.39
#
# lowest : 20.14459 20.44548 20.64488 20.75135 21.07784
# highest: 88.94552 89.11559 89.41095 89.59663 89.82740
# --------------------------------------------------------------------------------
# forward_low_range
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1       10    6.687    1.006    2.030
#      .25      .50      .75      .90      .95
#    5.021   10.022   14.984   17.981   18.964
#
# lowest :  0.009510468  0.084962878  0.166356104  0.245769520  0.311281868
# highest: 19.673070627 19.751589865 19.806227219 19.882724495 19.950052600
# --------------------------------------------------------------------------------
# forward_hi_range
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1      400    267.5    39.94    81.16
#      .25      .50      .75      .90      .95
#   199.79   400.06   598.81   717.92   757.68
#
# lowest :   0.8156544   3.0650284   6.8776892   8.7445713  11.1126343
# highest: 789.0418126 790.4110515 792.4113208 795.8649570 799.5801063
# --------------------------------------------------------------------------------
# forward_p_detect
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1     0.75   0.1672   0.5264   0.5510
#      .25      .50      .75      .90      .95
#   0.6257   0.7498   0.8740   0.9499   0.9744
#
# lowest : 0.5014215 0.5029558 0.5042484 0.5060689 0.5080395
# highest: 0.9920368 0.9942147 0.9963375 0.9979912 0.9988126
# --------------------------------------------------------------------------------
# current.heading
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1    179.5      120    18.76    36.03
#      .25      .50      .75      .90      .95
#    89.56   179.65   268.75   322.30   339.96
#
# lowest :   0.1674588   2.2601515   2.6434294   4.2730931   5.1999030
# highest: 353.2394643 354.6210539 355.9249266 356.9186812 358.1166140
# --------------------------------------------------------------------------------
# drift.speed
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#      300        0      300        1        1   0.6688   0.1054   0.2007
#      .25      .50      .75      .90      .95
#   0.5010   0.9973   1.4987   1.7987   1.8948
#
# lowest : 0.0006920938 0.0113827507 0.0175761565 0.0259358323 0.0272716350
# highest: 1.9682866135 1.9791872463 1.9853827337 1.9877458540 1.9983389218
# --------------------------------------------------------------------------------

# %%
boxplot(data[c('uuv.speed','objective.mine.speed')])
# Out:
# plot without title

# %%
boxplot(objective.mine.speed~turn.radius, data=data)
# Out:
# plot without title

# %%
plot(objective.mine.speed~max.obs.dist, data=data)
# Out:
# plot without title

# %%
plot(results$experiment.number, results$objective.mine.speed)
# Out:
# plot without title

# %%
plot(doe$nav.bearing.std, doe$nav.velocity.std.cm)
# Out:
# plot without title

# %%
describe(data$nav.velocity.std.cm)
# Out:
# data$nav.velocity.std.cm
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#     3000        0      300        1    4.999    3.334   0.5242   1.0020
#      .25      .50      .75      .90      .95
#   2.4973   5.0000   7.4919   8.9887   9.4987
#
# lowest : 0.009407459 0.040172059 0.098107403 0.118413681 0.163869569
# highest: 9.846594501 9.873609642 9.902930210 9.963935590 9.991333958

# %%
describe(data$nav.bearing.std)
# Out:
# data$nav.bearing.std
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#     3000        0      300        1        2    1.334   0.2106   0.4105
#      .25      .50      .75      .90      .95
#   1.0048   1.9949   2.9968   3.5942   3.7994
#
# lowest : 0.006041339 0.026104244 0.035969792 0.046252233 0.058515818
# highest: 3.934274962 3.950838657 3.968308243 3.983217214 3.998550054

# %%
interaction.plot(x.factor=forward_angle, uuv.speed, data$objective.mine.speed)
# Out:
# Error in tapply(response, list(x.factor, trace.factor), fun): object 'forward_angle' not found
# Traceback:
#
# 1. interaction.plot(forward_angle, uuv.speed, data$objective.mine.speed)
# 2. tapply(response, list(x.factor, trace.factor), fun)

# %%
cutspeed <- cut(doe$uuv.speed, breaks=c(0,1,2,3,4,5),labels=c(1,2,3,4,5))
describe(cutspeed)
# Out:
# cutspeed
#        n  missing distinct
#      300        0        2
#
# Value        3   4
# Frequency  150 150
# Proportion 0.5 0.5

# %%
boxplot(cut(doe$side_angle, breaks=c(30,40,50,60,70), labels=c("a","b","c","d")), data$objective.mine.speed)
# Out:
# plot without title

# %%
library(dplyr)

# %%
head(select(data, objective.mine.speed))
# Out:
#   objective.mine.speed
# 1 -14.800
# 2 -14.200
# 3 -16.725
# 4 -14.775
# 5  -3.772
# 6  -4.165

# %%
data %>% 
    group_by(experiment.number) %>% 
    summarise(mean=mean(objective.mine.speed),
             max=max(objective.mine.speed),
             min=min(objective.mine.speed),
             median=median(objective.mine.speed)) %>% 
    head
# Out:
#   experiment.number mean    max    min     median
# 1 0                 -9.2964 -3.021 -16.725 -9.1825
# 2 1                 -9.2048 -3.563 -14.650 -9.6965
# 3 2                 -9.0013 -3.019 -14.850 -8.7970
# 4 3                 -6.5789 -3.016 -13.950 -4.4765
# 5 4                 -7.8522 -3.433 -14.975 -4.5710
# 6 5                 -7.7919 -3.493 -14.900 -5.0830

# %%
data %>% group_by(experiment.number)
